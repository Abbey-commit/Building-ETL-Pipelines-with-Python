# %%
# Import Pandas
import pandas as pd

# %%
df = pd.read_csv('h9gi-nx95.csv')

# %%
df.head(5)
# Out:
#                 crash_date crash_time   borough  zip_code   latitude  \
# 0  2021-09-11T00:00:00.000       2:39       NaN       NaN        NaN
# 1  2022-03-26T00:00:00.000      11:45       NaN       NaN        NaN
# 2  2022-06-29T00:00:00.000       6:55       NaN       NaN        NaN
# 3  2021-09-11T00:00:00.000       9:35  BROOKLYN   11208.0  40.667202
# 4  2021-12-14T00:00:00.000       8:13  BROOKLYN   11233.0  40.683304
#
#    longitude                        location           on_street_name  \
# 0        NaN                             NaN    WHITESTONE EXPRESSWAY
# 1        NaN                             NaN  QUEENSBORO BRIDGE UPPER
# 2        NaN                             NaN       THROGS NECK BRIDGE
# 3 -73.866500    \n,  \n(40.667202, -73.8665)                      NaN
# 4 -73.917274  \n,  \n(40.683304, -73.917274)          SARATOGA AVENUE
#
#   off_street_name        cross_street_name  ...  \
# 0       20 AVENUE                      NaN  ...
# ...

# %%
# !pip install pyarrow

# %%
#import pyarrow 

df_parquet = pd.read_parquet('yellow_tripdata_2022-01.parquet')

# %%
df_parquet.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# Import API-related Python modules import json
import certifi
import urllib3
from urllib3 import request

# %%
import requests

# Define the API URL
api_url = 'https://data.cityofnewyork.us/resource/h9gi-nx95.json?$limit=500'

# Make an HTTP GET request to the API
response = requests.get(api_url)

# Check the status code
api_status = response.status_code

# Verify if the status code is 200 (successful connection)
if api_status == 200:
    # Parse the JSON data from the response
    data = response.json()
    
    # Nopw 'data' contains the retrieved data from the API
    # You can process it further or load it into a Pandas DataFrame
    print("Data retrieved successfully!")
    
else:
    print(f"Error: Unable to retrieve data. Status code: {api_status}")
# Out:
# Data retrieved successfully!
